# %%
from localization import monte_carlo
import matplotlib.pyplot as plt

from pathfinding import GraphMap, Map, Obstacle
o1 = Obstacle(1, 1, 5, 5)
o2 = Obstacle(6, 6, 9, 9)
map = Map(20, 20, [o1, o2], [])


map=monte_carlo.OccupationMap.from_Map(map)

print("Map size:", map.boundary)
print("Map obstacles:", map.obstacles) 
map.plot()
plt.show()
# Out:
# Map size: POLYGON ((0 0, 20 0, 20 20, 0 20, 0 0))
# Map obstacles: [<POLYGON ((1 1, 6 1, 6 6, 1 6, 1 1))>, <POLYGON ((6 6, 15 6, 15 15, 6 15, 6 6))>]
